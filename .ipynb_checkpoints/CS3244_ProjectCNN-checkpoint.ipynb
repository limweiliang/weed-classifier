# %% [markdown]
# <a href="https://colab.research.google.com/github/limweiliang/weed-classifier/blob/main/CS3244_ProjectCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Nov  8 17:42:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 496.49       Driver Version: 496.49       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   54C    P8    10W /  N/A |   1480MiB /  6144MiB |     20%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3364    C+G   ...\PowerToys.FancyZones.exe    N/A      |
# |    0   N/A  N/A      4596    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      8352    C+G   ...root\Office16\OUTLOOK.EXE    N/A      |
# |    0   N/A  N/A      9464      C   ...Data\Anaconda3\python.exe    N/A      |
# |    0   N/A  N/A      9772    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     10380    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     11364    C+G   ...gram Desktop\Telegram.exe    N/A      |
# |    0   N/A  N/A     14072    C+G   ... Host\Razer Synapse 3.exe    N/A      |
# |    0   N/A  N/A     16160    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A     17592    C+G   ...nputApp\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     18960    C+G   ...arp.BrowserSubprocess.exe    N/A      |
# |    0   N/A  N/A     21012    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     23424    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     24376    C+G   ...Roaming\Zoom\bin\Zoom.exe    N/A      |
# |    0   N/A  N/A     28436    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
import cv2
import numpy as np
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import sklearn
import math
import tensorflow_addons as tfa

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Define constants
RANDOM_STATE = 4242
NUM_CLASSES = 9

# ds = tfds.load('deep_weeds', batch_size = -1, as_supervised= True)
# images, labels = ds['train'] # Type: EagerTensor

# # Shuffle the dataset
# images = tf.random.shuffle(images, seed=RANDOM_STATE)
# labels = tf.random.shuffle(labels, seed=RANDOM_STATE)

# print(images.shape, labels.shape)

# # Split dataset into train-val-test
# num_images = images.shape[0]
# last_train_image = math.floor(num_images * 0.6)
# last_val_image = math.floor(num_images * 0.8)

# X_train = images[:last_train_image]
# y_train = labels[:last_train_image]
# X_val = images[last_train_image:last_val_image]
# y_val = labels[last_train_image:last_val_image]
# X_test = images[last_val_image:]
# y_test = labels[last_val_image:]

# print(X_train.shape, X_val.shape, X_test.shape)

# %%
BATCH_SIZE = 128
AUTOTUNE = tf.data.AUTOTUNE

train_ds, validation_ds, test_ds = tfds.load('deep_weeds', as_supervised= True, shuffle_files= True, split=["train[:70%]", "train[70%:90%]", "train[90%:100%]"], batch_size = BATCH_SIZE)

print("Number of training samples: %d" % tf.data.experimental.cardinality(train_ds))
print("Number of validation samples: %d" % tf.data.experimental.cardinality(validation_ds))
print("Number of test samples: %d" % tf.data.experimental.cardinality(test_ds))

#Pre-Processing
def one_hot(img, label):
    return (img, tf.one_hot(label,9))

def add_grey_grad(img ,label):
    org_img = img
    img = tf.cast(img, float)
    #img = tf.expand_dims(img, axis = 0)
    gray = tf.image.rgb_to_grayscale(img)
    dy , dx = tf.image.image_gradients(gray)
    dmag = tf.math.sqrt(tf.add(tf.math.square(dy),tf.math.square(dx)))

    #Normalize to 0 - 255
    im_max = tf.math.reduce_max(dmag)
    im_min = tf.math.reduce_min(dmag)
    out = (tf.math.subtract(dmag, im_min) / (im_max - im_min)) * 255
    out = tf.expand_dims(tf.cast(out, tf.uint8), axis = 0)
    out = tfa.image.gaussian_filter2d(out[0])
    
    gray = tf.expand_dims(tf.cast(gray, tf.uint8), axis = 0)
    org_img = tf.concat([org_img,gray[0],out],-1)
    return (org_img, label)

train_ds = train_ds.map(one_hot)
validation_ds = validation_ds.map(one_hot)
test_ds = test_ds.map(one_hot)

train_ds = train_ds.map(add_grey_grad)
validation_ds = validation_ds.map(add_grey_grad)
test_ds = test_ds.map(add_grey_grad)


train_ds = train_ds.shuffle(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE).cache()
validation_ds = validation_ds.shuffle(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE).cache()
test_ds = test_ds.shuffle(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE).cache()
# Out:
# Number of training samples: 96
# Number of validation samples: 28
# Number of test samples: 14

# %%
# Clean up memory usage
# del ds
# del images
# del labels

# %%
from tensorflow.keras import datasets, layers, models, regularizers, Input
import datetime

# %%
inputs = Input(shape = (256,256,5), name = "Original_Image")
flip = layers.RandomFlip("horizontal_and_vertical")(inputs)
rotate = layers.RandomRotation((-0.5,0.5), fill_mode = "nearest")(flip)
rescale = layers.Rescaling(1/255)(rotate)

x = layers.Conv2D(64, (3,3), padding = "same", strides = 2)(rescale)
x = layers.Conv2D(64, (3,3), padding = "same", strides = 2)(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
block_1_output = layers.MaxPool2D()(x)

x = layers.Conv2D(128, (3,3), padding = "same")(block_1_output)
x = layers.Conv2D(128, (3,3), padding = "same")(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
block_2_output = layers.MaxPool2D()(x)

x = layers.Conv2D(128, (3,3), padding = "same", strides = 2)(block_2_output)
x = layers.Conv2D(128, (3,3), padding = "same", strides = 2)(x)
x = layers.BatchNormalization()(x)
block_3_output = layers.ReLU()(x)

x = layers.Flatten()(block_3_output)
x = layers.Dense(128)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(9, activation = 'softmax')(x)

model = tf.keras.Model(inputs, outputs, name="2_block_CNN")
model.summary()
# Out:
# Model: "2_block_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Original_Image (InputLayer)  [(None, 256, 256, 5)]     0
# _________________________________________________________________
# random_flip_29 (RandomFlip)  (None, 256, 256, 5)       0
# _________________________________________________________________
# random_rotation_29 (RandomRo (None, 256, 256, 5)       0
# _________________________________________________________________
# rescaling_29 (Rescaling)     (None, 256, 256, 5)       0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 128, 128, 64)      2944
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# re_lu_56 (ReLU)              (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# re_lu_57 (ReLU)              (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# re_lu_58 (ReLU)              (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 821,193
# Trainable params: 820,553
# Non-trainable params: 640
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate= 0.001)


model.compile(optimizer=optimizer,
              loss= 'categorical_crossentropy',
              metrics=["Precision", "Recall",'accuracy'])

# %%
model.summary()
# Out:
# Model: "2_block_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Original_Image (InputLayer)  [(None, 256, 256, 5)]     0
# _________________________________________________________________
# random_flip_29 (RandomFlip)  (None, 256, 256, 5)       0
# _________________________________________________________________
# random_rotation_29 (RandomRo (None, 256, 256, 5)       0
# _________________________________________________________________
# rescaling_29 (Rescaling)     (None, 256, 256, 5)       0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 128, 128, 64)      2944
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# re_lu_56 (ReLU)              (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# re_lu_57 (ReLU)              (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# re_lu_58 (ReLU)              (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 821,193
# Trainable params: 820,553
# Non-trainable params: 640
# _________________________________________________________________

# %%
EarlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True , verbose = 1)

#Constant learning rate for first N epochs then it decreases exponentially
# def scheduler(epoch, lr):
#   if epoch < 65:
#     return lr
#   else:
#     return lr * tf.math.exp(-0.1/5)

# lr_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.6,
                              patience=5, cooldown=10, verbose = 1)

checkpoint_filepath = "./CNN_Models/3_block_cnn/3_blockV2.h5"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose = 1)

# %%
hist = model.fit(train_ds, epochs=200,
                     validation_data= validation_ds, callbacks=[EarlyStop, reduce_lr, model_checkpoint_callback],batch_size = BATCH_SIZE)
# Out:
# Epoch 1/200
# 96/96 [==============================] - 23s 239ms/step - loss: 1.0511 - precision: 0.7516 - recall: 0.5198 - accuracy: 0.6372 - val_loss: 1.3471 - val_precision: 0.6283 - val_recall: 0.3992 - val_accuracy: 0.5260
#
# Epoch 00001: val_loss improved from inf to 1.34711, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 2/200
# 96/96 [==============================] - 23s 240ms/step - loss: 0.9994 - precision: 0.7590 - recall: 0.5379 - accuracy: 0.6499 - val_loss: 1.4196 - val_precision: 0.6420 - val_recall: 0.5188 - val_accuracy: 0.5794
#
# Epoch 00002: val_loss did not improve from 1.34711
# Epoch 3/200
# 96/96 [==============================] - 23s 243ms/step - loss: 0.9390 - precision: 0.7759 - recall: 0.5647 - accuracy: 0.6687 - val_loss: 1.3848 - val_precision: 0.6756 - val_recall: 0.5500 - val_accuracy: 0.5982
#
# Epoch 00003: val_loss did not improve from 1.34711
# Epoch 4/200
# 96/96 [==============================] - 23s 239ms/step - loss: 0.8877 - precision: 0.7850 - recall: 0.5907 - accuracy: 0.6935 - val_loss: 1.2783 - val_precision: 0.6241 - val_recall: 0.4740 - val_accuracy: 0.5483
#
# Epoch 00004: val_loss improved from 1.34711 to 1.27835, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 5/200
# 96/96 [==============================] - 23s 238ms/step - loss: 0.8384 - precision: 0.7978 - recall: 0.6195 - accuracy: 0.7081 - val_loss: 1.2302 - val_precision: 0.7071 - val_recall: 0.5688 - val_accuracy: 0.6331
#
# Epoch 00005: val_loss improved from 1.27835 to 1.23022, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 6/200
# 96/96 [==============================] - 24s 247ms/step - loss: 0.8081 - precision: 0.8046 - recall: 0.6330 - accuracy: 0.7182 - val_loss: 1.3747 - val_precision: 0.6479 - val_recall: 0.5448 - val_accuracy: 0.5917
#
# Epoch 00006: val_loss did not improve from 1.23022
# Epoch 7/200
# 96/96 [==============================] - 23s 244ms/step - loss: 0.7788 - precision: 0.8142 - recall: 0.6502 - accuracy: 0.7281 - val_loss: 1.4280 - val_precision: 0.6029 - val_recall: 0.5143 - val_accuracy: 0.5588
#
# Epoch 00007: val_loss did not improve from 1.23022
# Epoch 8/200
# 96/96 [==============================] - 24s 245ms/step - loss: 0.7386 - precision: 0.8208 - recall: 0.6644 - accuracy: 0.7372 - val_loss: 1.0935 - val_precision: 0.7029 - val_recall: 0.6045 - val_accuracy: 0.6459
#
# Epoch 00008: val_loss improved from 1.23022 to 1.09351, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 9/200
# 96/96 [==============================] - 24s 253ms/step - loss: 0.6911 - precision: 0.8328 - recall: 0.6919 - accuracy: 0.7597 - val_loss: 1.0006 - val_precision: 0.7368 - val_recall: 0.6388 - val_accuracy: 0.6836
#
# Epoch 00009: val_loss improved from 1.09351 to 1.00056, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 10/200
# 96/96 [==============================] - 25s 259ms/step - loss: 0.6766 - precision: 0.8318 - recall: 0.6982 - accuracy: 0.7657 - val_loss: 1.0169 - val_precision: 0.7185 - val_recall: 0.6305 - val_accuracy: 0.6716
#
# Epoch 00010: val_loss did not improve from 1.00056
# Epoch 11/200
# 96/96 [==============================] - 24s 255ms/step - loss: 0.6693 - precision: 0.8354 - recall: 0.7023 - accuracy: 0.7658 - val_loss: 0.9772 - val_precision: 0.7226 - val_recall: 0.6739 - val_accuracy: 0.6976
#
# Epoch 00011: val_loss improved from 1.00056 to 0.97722, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 12/200
# 96/96 [==============================] - 25s 260ms/step - loss: 0.6488 - precision: 0.8365 - recall: 0.7136 - accuracy: 0.7752 - val_loss: 1.2898 - val_precision: 0.6816 - val_recall: 0.6351 - val_accuracy: 0.6593
#
# Epoch 00012: val_loss did not improve from 0.97722
# Epoch 13/200
# 96/96 [==============================] - 25s 258ms/step - loss: 0.6208 - precision: 0.8452 - recall: 0.7268 - accuracy: 0.7839 - val_loss: 0.9951 - val_precision: 0.7305 - val_recall: 0.6742 - val_accuracy: 0.6999
#
# Epoch 00013: val_loss did not improve from 0.97722
# Epoch 14/200
# 96/96 [==============================] - 25s 261ms/step - loss: 0.6076 - precision: 0.8428 - recall: 0.7272 - accuracy: 0.7856 - val_loss: 0.7827 - val_precision: 0.7866 - val_recall: 0.7033 - val_accuracy: 0.7424
#
# Epoch 00014: val_loss improved from 0.97722 to 0.78265, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 15/200
# 96/96 [==============================] - 25s 264ms/step - loss: 0.5981 - precision: 0.8480 - recall: 0.7329 - accuracy: 0.7894 - val_loss: 1.0105 - val_precision: 0.7341 - val_recall: 0.6850 - val_accuracy: 0.7022
#
# Epoch 00015: val_loss did not improve from 0.78265
# Epoch 16/200
# 96/96 [==============================] - 25s 262ms/step - loss: 0.5686 - precision: 0.8545 - recall: 0.7494 - accuracy: 0.8016 - val_loss: 0.7958 - val_precision: 0.7915 - val_recall: 0.7113 - val_accuracy: 0.7427
#
# Epoch 00016: val_loss did not improve from 0.78265
# Epoch 17/200
# 96/96 [==============================] - 33s 347ms/step - loss: 0.5606 - precision: 0.8539 - recall: 0.7516 - accuracy: 0.8026 - val_loss: 1.0890 - val_precision: 0.7323 - val_recall: 0.6833 - val_accuracy: 0.7050
#
# Epoch 00017: val_loss did not improve from 0.78265
# Epoch 18/200
# 96/96 [==============================] - 27s 284ms/step - loss: 0.5361 - precision: 0.8602 - recall: 0.7633 - accuracy: 0.8119 - val_loss: 1.0679 - val_precision: 0.7224 - val_recall: 0.6725 - val_accuracy: 0.6927
#
# Epoch 00018: val_loss did not improve from 0.78265
# Epoch 19/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.5192 - precision: 0.8667 - recall: 0.7732 - accuracy: 0.8180 - val_loss: 0.9436 - val_precision: 0.7527 - val_recall: 0.6927 - val_accuracy: 0.7227
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
#
# Epoch 00019: val_loss did not improve from 0.78265
# Epoch 20/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.4642 - precision: 0.8819 - recall: 0.7941 - accuracy: 0.8369 - val_loss: 0.7454 - val_precision: 0.8062 - val_recall: 0.7424 - val_accuracy: 0.7713
#
# Epoch 00020: val_loss improved from 0.78265 to 0.74540, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 21/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.4537 - precision: 0.8793 - recall: 0.8009 - accuracy: 0.8385 - val_loss: 0.8696 - val_precision: 0.7708 - val_recall: 0.7116 - val_accuracy: 0.7356
#
# Epoch 00021: val_loss did not improve from 0.74540
# Epoch 22/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.4396 - precision: 0.8838 - recall: 0.8056 - accuracy: 0.8438 - val_loss: 0.6541 - val_precision: 0.8225 - val_recall: 0.7647 - val_accuracy: 0.7875
#
# Epoch 00022: val_loss improved from 0.74540 to 0.65409, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 23/200
# 96/96 [==============================] - 25s 266ms/step - loss: 0.4278 - precision: 0.8883 - recall: 0.8154 - accuracy: 0.8499 - val_loss: 0.6917 - val_precision: 0.8092 - val_recall: 0.7421 - val_accuracy: 0.7724
#
# Epoch 00023: val_loss did not improve from 0.65409
# Epoch 24/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.4200 - precision: 0.8894 - recall: 0.8140 - accuracy: 0.8498 - val_loss: 0.7493 - val_precision: 0.7976 - val_recall: 0.7493 - val_accuracy: 0.7704
#
# Epoch 00024: val_loss did not improve from 0.65409
# Epoch 25/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.4076 - precision: 0.8917 - recall: 0.8216 - accuracy: 0.8579 - val_loss: 0.6140 - val_precision: 0.8309 - val_recall: 0.7773 - val_accuracy: 0.7973
#
# Epoch 00025: val_loss improved from 0.65409 to 0.61402, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 26/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.4037 - precision: 0.8913 - recall: 0.8266 - accuracy: 0.8557 - val_loss: 0.9426 - val_precision: 0.7733 - val_recall: 0.7364 - val_accuracy: 0.7504
#
# Epoch 00026: val_loss did not improve from 0.61402
# Epoch 27/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.3959 - precision: 0.8917 - recall: 0.8295 - accuracy: 0.8595 - val_loss: 0.5656 - val_precision: 0.8398 - val_recall: 0.7798 - val_accuracy: 0.8075
#
# Epoch 00027: val_loss improved from 0.61402 to 0.56561, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 28/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.3852 - precision: 0.8975 - recall: 0.8352 - accuracy: 0.8673 - val_loss: 0.6050 - val_precision: 0.8319 - val_recall: 0.7741 - val_accuracy: 0.8030
#
# Epoch 00028: val_loss did not improve from 0.56561
# Epoch 29/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.3836 - precision: 0.8942 - recall: 0.8344 - accuracy: 0.8633 - val_loss: 0.8305 - val_precision: 0.7871 - val_recall: 0.7413 - val_accuracy: 0.7593
#
# Epoch 00029: val_loss did not improve from 0.56561
# Epoch 30/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.3785 - precision: 0.8948 - recall: 0.8368 - accuracy: 0.8674 - val_loss: 0.6537 - val_precision: 0.8213 - val_recall: 0.7718 - val_accuracy: 0.7955
#
# Epoch 00030: val_loss did not improve from 0.56561
# Epoch 31/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.3803 - precision: 0.8948 - recall: 0.8402 - accuracy: 0.8651 - val_loss: 0.9818 - val_precision: 0.7590 - val_recall: 0.7239 - val_accuracy: 0.7379
#
# Epoch 00031: val_loss did not improve from 0.56561
# Epoch 32/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.3682 - precision: 0.9008 - recall: 0.8428 - accuracy: 0.8718 - val_loss: 0.7420 - val_precision: 0.8090 - val_recall: 0.7681 - val_accuracy: 0.7844
#
# Epoch 00032: val_loss did not improve from 0.56561
# Epoch 33/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.3594 - precision: 0.8999 - recall: 0.8455 - accuracy: 0.8738 - val_loss: 0.7921 - val_precision: 0.8013 - val_recall: 0.7564 - val_accuracy: 0.7753
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
#
# Epoch 00033: val_loss did not improve from 0.56561
# Epoch 34/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.3183 - precision: 0.9145 - recall: 0.8618 - accuracy: 0.8884 - val_loss: 0.5922 - val_precision: 0.8322 - val_recall: 0.7887 - val_accuracy: 0.8030
#
# Epoch 00034: val_loss did not improve from 0.56561
# Epoch 35/200
# 96/96 [==============================] - 26s 267ms/step - loss: 0.3166 - precision: 0.9153 - recall: 0.8694 - accuracy: 0.8919 - val_loss: 0.6220 - val_precision: 0.8235 - val_recall: 0.7716 - val_accuracy: 0.7938
#
# Epoch 00035: val_loss did not improve from 0.56561
# Epoch 36/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.3025 - precision: 0.9145 - recall: 0.8711 - accuracy: 0.8914 - val_loss: 0.7804 - val_precision: 0.7932 - val_recall: 0.7439 - val_accuracy: 0.7638
#
# Epoch 00036: val_loss did not improve from 0.56561
# Epoch 37/200
# 96/96 [==============================] - 25s 266ms/step - loss: 0.2986 - precision: 0.9205 - recall: 0.8738 - accuracy: 0.8965 - val_loss: 0.6473 - val_precision: 0.8135 - val_recall: 0.7724 - val_accuracy: 0.7924
#
# Epoch 00037: val_loss did not improve from 0.56561
# Epoch 38/200
# 96/96 [==============================] - 25s 261ms/step - loss: 0.2926 - precision: 0.9199 - recall: 0.8770 - accuracy: 0.8990 - val_loss: 0.7798 - val_precision: 0.7999 - val_recall: 0.7601 - val_accuracy: 0.7773
#
# Epoch 00038: val_loss did not improve from 0.56561
# Epoch 39/200
# 96/96 [==============================] - 25s 259ms/step - loss: 0.2809 - precision: 0.9199 - recall: 0.8801 - accuracy: 0.8987 - val_loss: 0.5108 - val_precision: 0.8558 - val_recall: 0.8067 - val_accuracy: 0.8298
#
# Epoch 00039: val_loss improved from 0.56561 to 0.51081, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 40/200
# 96/96 [==============================] - 25s 260ms/step - loss: 0.2786 - precision: 0.9248 - recall: 0.8832 - accuracy: 0.9026 - val_loss: 0.7417 - val_precision: 0.8085 - val_recall: 0.7621 - val_accuracy: 0.7793
#
# Epoch 00040: val_loss did not improve from 0.51081
# Epoch 41/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.2797 - precision: 0.9218 - recall: 0.8816 - accuracy: 0.9027 - val_loss: 0.6590 - val_precision: 0.8254 - val_recall: 0.7818 - val_accuracy: 0.7964
#
# Epoch 00041: val_loss did not improve from 0.51081
# Epoch 42/200
# 96/96 [==============================] - 27s 285ms/step - loss: 0.2662 - precision: 0.9279 - recall: 0.8903 - accuracy: 0.9084 - val_loss: 0.4864 - val_precision: 0.8609 - val_recall: 0.8130 - val_accuracy: 0.8335
#
# Epoch 00042: val_loss improved from 0.51081 to 0.48636, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 43/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.2694 - precision: 0.9261 - recall: 0.8870 - accuracy: 0.9046 - val_loss: 0.6414 - val_precision: 0.8189 - val_recall: 0.7801 - val_accuracy: 0.7938
#
# Epoch 00043: val_loss did not improve from 0.48636
# Epoch 44/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.2727 - precision: 0.9243 - recall: 0.8881 - accuracy: 0.9049 - val_loss: 0.5792 - val_precision: 0.8237 - val_recall: 0.7750 - val_accuracy: 0.7967
#
# Epoch 00044: val_loss did not improve from 0.48636
# Epoch 45/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.2648 - precision: 0.9290 - recall: 0.8929 - accuracy: 0.9098 - val_loss: 0.6043 - val_precision: 0.8342 - val_recall: 0.7858 - val_accuracy: 0.8061
#
# Epoch 00045: val_loss did not improve from 0.48636
# Epoch 46/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.2579 - precision: 0.9287 - recall: 0.8929 - accuracy: 0.9110 - val_loss: 0.4545 - val_precision: 0.8715 - val_recall: 0.8330 - val_accuracy: 0.8484
#
# Epoch 00046: val_loss improved from 0.48636 to 0.45449, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 47/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.2464 - precision: 0.9305 - recall: 0.8972 - accuracy: 0.9139 - val_loss: 0.5626 - val_precision: 0.8416 - val_recall: 0.7844 - val_accuracy: 0.8095
#
# Epoch 00047: val_loss did not improve from 0.45449
# Epoch 48/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.2471 - precision: 0.9306 - recall: 0.8959 - accuracy: 0.9119 - val_loss: 0.4928 - val_precision: 0.8580 - val_recall: 0.8250 - val_accuracy: 0.8389
#
# Epoch 00048: val_loss did not improve from 0.45449
# Epoch 49/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.2467 - precision: 0.9306 - recall: 0.8964 - accuracy: 0.9129 - val_loss: 0.6675 - val_precision: 0.8122 - val_recall: 0.7696 - val_accuracy: 0.7864
#
# Epoch 00049: val_loss did not improve from 0.45449
# Epoch 50/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.2401 - precision: 0.9305 - recall: 0.8989 - accuracy: 0.9133 - val_loss: 0.6163 - val_precision: 0.8320 - val_recall: 0.7918 - val_accuracy: 0.8113
#
# Epoch 00050: val_loss did not improve from 0.45449
# Epoch 51/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.2399 - precision: 0.9338 - recall: 0.9005 - accuracy: 0.9162 - val_loss: 0.4845 - val_precision: 0.8607 - val_recall: 0.8272 - val_accuracy: 0.8435
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
#
# Epoch 00051: val_loss did not improve from 0.45449
# Epoch 52/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.2174 - precision: 0.9404 - recall: 0.9133 - accuracy: 0.9262 - val_loss: 0.3594 - val_precision: 0.8968 - val_recall: 0.8686 - val_accuracy: 0.8801
#
# Epoch 00052: val_loss improved from 0.45449 to 0.35939, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 53/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.2025 - precision: 0.9438 - recall: 0.9151 - accuracy: 0.9304 - val_loss: 0.4405 - val_precision: 0.8750 - val_recall: 0.8358 - val_accuracy: 0.8521
#
# Epoch 00053: val_loss did not improve from 0.35939
# Epoch 54/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.2059 - precision: 0.9439 - recall: 0.9148 - accuracy: 0.9282 - val_loss: 0.3957 - val_precision: 0.8889 - val_recall: 0.8589 - val_accuracy: 0.8726
#
# Epoch 00054: val_loss did not improve from 0.35939
# Epoch 55/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.2023 - precision: 0.9434 - recall: 0.9162 - accuracy: 0.9298 - val_loss: 0.4828 - val_precision: 0.8554 - val_recall: 0.8195 - val_accuracy: 0.8330
#
# Epoch 00055: val_loss did not improve from 0.35939
# Epoch 56/200
# 96/96 [==============================] - 27s 280ms/step - loss: 0.1912 - precision: 0.9462 - recall: 0.9221 - accuracy: 0.9345 - val_loss: 0.3577 - val_precision: 0.8947 - val_recall: 0.8638 - val_accuracy: 0.8778
#
# Epoch 00056: val_loss improved from 0.35939 to 0.35765, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 57/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1872 - precision: 0.9467 - recall: 0.9238 - accuracy: 0.9349 - val_loss: 0.3497 - val_precision: 0.8965 - val_recall: 0.8678 - val_accuracy: 0.8792
#
# Epoch 00057: val_loss improved from 0.35765 to 0.34965, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 58/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.1871 - precision: 0.9444 - recall: 0.9232 - accuracy: 0.9344 - val_loss: 0.4001 - val_precision: 0.8898 - val_recall: 0.8626 - val_accuracy: 0.8729
#
# Epoch 00058: val_loss did not improve from 0.34965
# Epoch 59/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1911 - precision: 0.9464 - recall: 0.9226 - accuracy: 0.9334 - val_loss: 0.4158 - val_precision: 0.8785 - val_recall: 0.8467 - val_accuracy: 0.8607
#
# Epoch 00059: val_loss did not improve from 0.34965
# Epoch 60/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.1843 - precision: 0.9480 - recall: 0.9236 - accuracy: 0.9360 - val_loss: 0.3994 - val_precision: 0.8825 - val_recall: 0.8489 - val_accuracy: 0.8624
#
# Epoch 00060: val_loss did not improve from 0.34965
# Epoch 61/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.1865 - precision: 0.9459 - recall: 0.9218 - accuracy: 0.9339 - val_loss: 0.4578 - val_precision: 0.8632 - val_recall: 0.8327 - val_accuracy: 0.8427
#
# Epoch 00061: val_loss did not improve from 0.34965
# Epoch 62/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1812 - precision: 0.9478 - recall: 0.9251 - accuracy: 0.9359 - val_loss: 0.4459 - val_precision: 0.8722 - val_recall: 0.8398 - val_accuracy: 0.8529
#
# Epoch 00062: val_loss did not improve from 0.34965
# Epoch 63/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.1751 - precision: 0.9512 - recall: 0.9294 - accuracy: 0.9413 - val_loss: 0.3462 - val_precision: 0.9017 - val_recall: 0.8752 - val_accuracy: 0.8849
#
# Epoch 00063: val_loss improved from 0.34965 to 0.34624, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 64/200
# 96/96 [==============================] - 26s 269ms/step - loss: 0.1759 - precision: 0.9497 - recall: 0.9280 - accuracy: 0.9386 - val_loss: 0.5122 - val_precision: 0.8566 - val_recall: 0.8307 - val_accuracy: 0.8435
#
# Epoch 00064: val_loss did not improve from 0.34624
# Epoch 65/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.1712 - precision: 0.9501 - recall: 0.9298 - accuracy: 0.9397 - val_loss: 0.4482 - val_precision: 0.8713 - val_recall: 0.8504 - val_accuracy: 0.8578
#
# Epoch 00065: val_loss did not improve from 0.34624
# Epoch 66/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1715 - precision: 0.9505 - recall: 0.9313 - accuracy: 0.9399 - val_loss: 0.4985 - val_precision: 0.8618 - val_recall: 0.8389 - val_accuracy: 0.8489
#
# Epoch 00066: val_loss did not improve from 0.34624
# Epoch 67/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1669 - precision: 0.9527 - recall: 0.9315 - accuracy: 0.9417 - val_loss: 0.3666 - val_precision: 0.8935 - val_recall: 0.8695 - val_accuracy: 0.8812
#
# Epoch 00067: val_loss did not improve from 0.34624
# Epoch 68/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.1658 - precision: 0.9517 - recall: 0.9335 - accuracy: 0.9427 - val_loss: 0.4379 - val_precision: 0.8750 - val_recall: 0.8435 - val_accuracy: 0.8578
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
#
# Epoch 00068: val_loss did not improve from 0.34624
# Epoch 69/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.1530 - precision: 0.9569 - recall: 0.9382 - accuracy: 0.9477 - val_loss: 0.4157 - val_precision: 0.8898 - val_recall: 0.8695 - val_accuracy: 0.8775
#
# Epoch 00069: val_loss did not improve from 0.34624
# Epoch 70/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1480 - precision: 0.9572 - recall: 0.9391 - accuracy: 0.9481 - val_loss: 0.3611 - val_precision: 0.8981 - val_recall: 0.8761 - val_accuracy: 0.8849
#
# Epoch 00070: val_loss did not improve from 0.34624
# Epoch 71/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.1455 - precision: 0.9577 - recall: 0.9402 - accuracy: 0.9483 - val_loss: 0.3927 - val_precision: 0.8887 - val_recall: 0.8712 - val_accuracy: 0.8781
#
# Epoch 00071: val_loss did not improve from 0.34624
# Epoch 72/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.1452 - precision: 0.9586 - recall: 0.9411 - accuracy: 0.9498 - val_loss: 0.3891 - val_precision: 0.8914 - val_recall: 0.8649 - val_accuracy: 0.8766
#
# Epoch 00072: val_loss did not improve from 0.34624
# Epoch 73/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.1410 - precision: 0.9573 - recall: 0.9411 - accuracy: 0.9498 - val_loss: 0.4351 - val_precision: 0.8819 - val_recall: 0.8589 - val_accuracy: 0.8681
#
# Epoch 00073: val_loss did not improve from 0.34624
# Epoch 74/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.1378 - precision: 0.9624 - recall: 0.9445 - accuracy: 0.9539 - val_loss: 0.3995 - val_precision: 0.8926 - val_recall: 0.8712 - val_accuracy: 0.8795
#
# Epoch 00074: val_loss did not improve from 0.34624
# Epoch 75/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.1402 - precision: 0.9593 - recall: 0.9443 - accuracy: 0.9514 - val_loss: 0.4623 - val_precision: 0.8736 - val_recall: 0.8507 - val_accuracy: 0.8607
#
# Epoch 00075: val_loss did not improve from 0.34624
# Epoch 76/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1337 - precision: 0.9613 - recall: 0.9456 - accuracy: 0.9529 - val_loss: 0.3904 - val_precision: 0.8876 - val_recall: 0.8681 - val_accuracy: 0.8758
#
# Epoch 00076: val_loss did not improve from 0.34624
# Epoch 77/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1356 - precision: 0.9616 - recall: 0.9453 - accuracy: 0.9524 - val_loss: 0.3788 - val_precision: 0.8958 - val_recall: 0.8741 - val_accuracy: 0.8852
#
# Epoch 00077: val_loss did not improve from 0.34624
# Epoch 78/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.1317 - precision: 0.9626 - recall: 0.9475 - accuracy: 0.9549 - val_loss: 0.4540 - val_precision: 0.8783 - val_recall: 0.8595 - val_accuracy: 0.8655
#
# Epoch 00078: val_loss did not improve from 0.34624
# Epoch 79/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1321 - precision: 0.9619 - recall: 0.9463 - accuracy: 0.9544 - val_loss: 0.3610 - val_precision: 0.8999 - val_recall: 0.8809 - val_accuracy: 0.8872
#
# Epoch 00079: val_loss did not improve from 0.34624
# Epoch 80/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1310 - precision: 0.9629 - recall: 0.9469 - accuracy: 0.9546 - val_loss: 0.4411 - val_precision: 0.8828 - val_recall: 0.8578 - val_accuracy: 0.8664
#
# Epoch 00080: val_loss did not improve from 0.34624
# Epoch 81/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1268 - precision: 0.9630 - recall: 0.9492 - accuracy: 0.9558 - val_loss: 0.3781 - val_precision: 0.8959 - val_recall: 0.8801 - val_accuracy: 0.8844
#
# Epoch 00081: val_loss did not improve from 0.34624
# Epoch 82/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.1298 - precision: 0.9615 - recall: 0.9478 - accuracy: 0.9552 - val_loss: 0.3433 - val_precision: 0.9027 - val_recall: 0.8821 - val_accuracy: 0.8898
#
# Epoch 00082: val_loss improved from 0.34624 to 0.34327, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 83/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.1242 - precision: 0.9652 - recall: 0.9496 - accuracy: 0.9574 - val_loss: 0.4357 - val_precision: 0.8785 - val_recall: 0.8632 - val_accuracy: 0.8701
#
# Epoch 00083: val_loss did not improve from 0.34327
# Epoch 84/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1248 - precision: 0.9654 - recall: 0.9510 - accuracy: 0.9572 - val_loss: 0.4035 - val_precision: 0.8917 - val_recall: 0.8746 - val_accuracy: 0.8829
#
# Epoch 00084: val_loss did not improve from 0.34327
# Epoch 85/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.1217 - precision: 0.9642 - recall: 0.9505 - accuracy: 0.9572 - val_loss: 0.4699 - val_precision: 0.8791 - val_recall: 0.8621 - val_accuracy: 0.8686
#
# Epoch 00085: val_loss did not improve from 0.34327
# Epoch 86/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1194 - precision: 0.9656 - recall: 0.9526 - accuracy: 0.9586 - val_loss: 0.4253 - val_precision: 0.8841 - val_recall: 0.8624 - val_accuracy: 0.8715
#
# Epoch 00086: val_loss did not improve from 0.34327
# Epoch 87/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.1237 - precision: 0.9642 - recall: 0.9517 - accuracy: 0.9580 - val_loss: 0.4125 - val_precision: 0.8893 - val_recall: 0.8698 - val_accuracy: 0.8781
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
#
# Epoch 00087: val_loss did not improve from 0.34327
# Epoch 88/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.1086 - precision: 0.9712 - recall: 0.9586 - accuracy: 0.9642 - val_loss: 0.3412 - val_precision: 0.9061 - val_recall: 0.8901 - val_accuracy: 0.8955
#
# Epoch 00088: val_loss improved from 0.34327 to 0.34124, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 89/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1050 - precision: 0.9691 - recall: 0.9590 - accuracy: 0.9634 - val_loss: 0.3293 - val_precision: 0.9102 - val_recall: 0.8969 - val_accuracy: 0.9021
#
# Epoch 00089: val_loss improved from 0.34124 to 0.32926, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 90/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.1067 - precision: 0.9710 - recall: 0.9599 - accuracy: 0.9648 - val_loss: 0.3505 - val_precision: 0.9064 - val_recall: 0.8909 - val_accuracy: 0.8986
#
# Epoch 00090: val_loss did not improve from 0.32926
# Epoch 91/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.1056 - precision: 0.9701 - recall: 0.9579 - accuracy: 0.9641 - val_loss: 0.3758 - val_precision: 0.9013 - val_recall: 0.8835 - val_accuracy: 0.8918
#
# Epoch 00091: val_loss did not improve from 0.32926
# Epoch 92/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.1063 - precision: 0.9698 - recall: 0.9576 - accuracy: 0.9619 - val_loss: 0.3701 - val_precision: 0.9031 - val_recall: 0.8886 - val_accuracy: 0.8952
#
# Epoch 00092: val_loss did not improve from 0.32926
# Epoch 93/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0987 - precision: 0.9717 - recall: 0.9607 - accuracy: 0.9670 - val_loss: 0.3442 - val_precision: 0.9063 - val_recall: 0.8923 - val_accuracy: 0.8972
#
# Epoch 00093: val_loss did not improve from 0.32926
# Epoch 94/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.1032 - precision: 0.9710 - recall: 0.9606 - accuracy: 0.9654 - val_loss: 0.3290 - val_precision: 0.9097 - val_recall: 0.8943 - val_accuracy: 0.8981
#
# Epoch 00094: val_loss improved from 0.32926 to 0.32904, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 95/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.1037 - precision: 0.9690 - recall: 0.9587 - accuracy: 0.9642 - val_loss: 0.3968 - val_precision: 0.8980 - val_recall: 0.8849 - val_accuracy: 0.8906
#
# Epoch 00095: val_loss did not improve from 0.32904
# Epoch 96/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.0982 - precision: 0.9710 - recall: 0.9602 - accuracy: 0.9656 - val_loss: 0.3470 - val_precision: 0.9092 - val_recall: 0.8926 - val_accuracy: 0.8989
#
# Epoch 00096: val_loss did not improve from 0.32904
# Epoch 97/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.1033 - precision: 0.9707 - recall: 0.9595 - accuracy: 0.9656 - val_loss: 0.3544 - val_precision: 0.9048 - val_recall: 0.8903 - val_accuracy: 0.8958
#
# Epoch 00097: val_loss did not improve from 0.32904
# Epoch 98/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.0988 - precision: 0.9724 - recall: 0.9628 - accuracy: 0.9679 - val_loss: 0.3732 - val_precision: 0.9029 - val_recall: 0.8869 - val_accuracy: 0.8915
#
# Epoch 00098: val_loss did not improve from 0.32904
# Epoch 99/200
# 96/96 [==============================] - 28s 289ms/step - loss: 0.0963 - precision: 0.9724 - recall: 0.9627 - accuracy: 0.9674 - val_loss: 0.3674 - val_precision: 0.9040 - val_recall: 0.8844 - val_accuracy: 0.8935
#
# Epoch 00099: val_loss did not improve from 0.32904
# Epoch 100/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.0993 - precision: 0.9735 - recall: 0.9625 - accuracy: 0.9678 - val_loss: 0.3787 - val_precision: 0.9032 - val_recall: 0.8875 - val_accuracy: 0.8935
#
# Epoch 00100: val_loss did not improve from 0.32904
# Epoch 101/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.1003 - precision: 0.9717 - recall: 0.9599 - accuracy: 0.9659 - val_loss: 0.3639 - val_precision: 0.9074 - val_recall: 0.8926 - val_accuracy: 0.8986
#
# Epoch 00101: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
#
# Epoch 00101: val_loss did not improve from 0.32904
# Epoch 102/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0960 - precision: 0.9734 - recall: 0.9630 - accuracy: 0.9674 - val_loss: 0.3556 - val_precision: 0.9051 - val_recall: 0.8929 - val_accuracy: 0.8983
#
# Epoch 00102: val_loss did not improve from 0.32904
# Epoch 103/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.0922 - precision: 0.9747 - recall: 0.9650 - accuracy: 0.9698 - val_loss: 0.3459 - val_precision: 0.9026 - val_recall: 0.8915 - val_accuracy: 0.8958
#
# Epoch 00103: val_loss did not improve from 0.32904
# Epoch 104/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0881 - precision: 0.9752 - recall: 0.9650 - accuracy: 0.9700 - val_loss: 0.3331 - val_precision: 0.9085 - val_recall: 0.8932 - val_accuracy: 0.9006
#
# Epoch 00104: val_loss did not improve from 0.32904
# Epoch 105/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.0885 - precision: 0.9737 - recall: 0.9647 - accuracy: 0.9683 - val_loss: 0.3529 - val_precision: 0.9037 - val_recall: 0.8895 - val_accuracy: 0.8955
#
# Epoch 00105: val_loss did not improve from 0.32904
# Epoch 106/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.0817 - precision: 0.9764 - recall: 0.9670 - accuracy: 0.9720 - val_loss: 0.3640 - val_precision: 0.9035 - val_recall: 0.8901 - val_accuracy: 0.8961
#
# Epoch 00106: val_loss did not improve from 0.32904
# Epoch 107/200
# 96/96 [==============================] - 27s 284ms/step - loss: 0.0913 - precision: 0.9741 - recall: 0.9656 - accuracy: 0.9693 - val_loss: 0.3321 - val_precision: 0.9141 - val_recall: 0.8992 - val_accuracy: 0.9046
#
# Epoch 00107: val_loss did not improve from 0.32904
# Epoch 108/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0844 - precision: 0.9763 - recall: 0.9683 - accuracy: 0.9721 - val_loss: 0.3527 - val_precision: 0.9098 - val_recall: 0.8958 - val_accuracy: 0.9023
#
# Epoch 00108: val_loss did not improve from 0.32904
# Epoch 109/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.0851 - precision: 0.9758 - recall: 0.9669 - accuracy: 0.9714 - val_loss: 0.3624 - val_precision: 0.9077 - val_recall: 0.8932 - val_accuracy: 0.8975
#
# Epoch 00109: val_loss did not improve from 0.32904
# Epoch 110/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.0874 - precision: 0.9735 - recall: 0.9657 - accuracy: 0.9697 - val_loss: 0.3535 - val_precision: 0.9098 - val_recall: 0.8932 - val_accuracy: 0.8995
#
# Epoch 00110: val_loss did not improve from 0.32904
# Epoch 111/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0823 - precision: 0.9766 - recall: 0.9688 - accuracy: 0.9723 - val_loss: 0.3620 - val_precision: 0.9059 - val_recall: 0.8909 - val_accuracy: 0.8975
#
# Epoch 00111: val_loss did not improve from 0.32904
# Epoch 112/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.0889 - precision: 0.9741 - recall: 0.9661 - accuracy: 0.9708 - val_loss: 0.3465 - val_precision: 0.9099 - val_recall: 0.8938 - val_accuracy: 0.9003
#
# Epoch 00112: val_loss did not improve from 0.32904
# Epoch 113/200
# 96/96 [==============================] - 27s 281ms/step - loss: 0.0844 - precision: 0.9762 - recall: 0.9660 - accuracy: 0.9717 - val_loss: 0.3397 - val_precision: 0.9104 - val_recall: 0.8966 - val_accuracy: 0.9029
#
# Epoch 00113: val_loss did not improve from 0.32904
# Epoch 114/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0821 - precision: 0.9770 - recall: 0.9691 - accuracy: 0.9731 - val_loss: 0.3727 - val_precision: 0.9066 - val_recall: 0.8921 - val_accuracy: 0.8966
#
# Epoch 00114: val_loss did not improve from 0.32904
# Epoch 115/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.0823 - precision: 0.9774 - recall: 0.9694 - accuracy: 0.9729 - val_loss: 0.3526 - val_precision: 0.9126 - val_recall: 0.8969 - val_accuracy: 0.9052
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
#
# Epoch 00115: val_loss did not improve from 0.32904
# Epoch 116/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.0810 - precision: 0.9761 - recall: 0.9684 - accuracy: 0.9730 - val_loss: 0.3250 - val_precision: 0.9177 - val_recall: 0.9041 - val_accuracy: 0.9086
#
# Epoch 00116: val_loss improved from 0.32904 to 0.32502, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 117/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.0777 - precision: 0.9790 - recall: 0.9711 - accuracy: 0.9752 - val_loss: 0.3397 - val_precision: 0.9141 - val_recall: 0.8989 - val_accuracy: 0.9035
#
# Epoch 00117: val_loss did not improve from 0.32502
# Epoch 118/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0800 - precision: 0.9765 - recall: 0.9692 - accuracy: 0.9729 - val_loss: 0.3427 - val_precision: 0.9127 - val_recall: 0.8983 - val_accuracy: 0.9038
#
# Epoch 00118: val_loss did not improve from 0.32502
# Epoch 119/200
# 96/96 [==============================] - 26s 270ms/step - loss: 0.0776 - precision: 0.9783 - recall: 0.9692 - accuracy: 0.9743 - val_loss: 0.3376 - val_precision: 0.9128 - val_recall: 0.8995 - val_accuracy: 0.9041
#
# Epoch 00119: val_loss did not improve from 0.32502
# Epoch 120/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0803 - precision: 0.9771 - recall: 0.9695 - accuracy: 0.9730 - val_loss: 0.3415 - val_precision: 0.9168 - val_recall: 0.9035 - val_accuracy: 0.9086
#
# Epoch 00120: val_loss did not improve from 0.32502
# Epoch 121/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.0741 - precision: 0.9800 - recall: 0.9718 - accuracy: 0.9759 - val_loss: 0.3349 - val_precision: 0.9138 - val_recall: 0.8989 - val_accuracy: 0.9046
#
# Epoch 00121: val_loss did not improve from 0.32502
# Epoch 122/200
# 96/96 [==============================] - 27s 285ms/step - loss: 0.0763 - precision: 0.9783 - recall: 0.9718 - accuracy: 0.9757 - val_loss: 0.3341 - val_precision: 0.9140 - val_recall: 0.8981 - val_accuracy: 0.9055
#
# Epoch 00122: val_loss did not improve from 0.32502
# Epoch 123/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0756 - precision: 0.9772 - recall: 0.9698 - accuracy: 0.9738 - val_loss: 0.3386 - val_precision: 0.9129 - val_recall: 0.8978 - val_accuracy: 0.9055
#
# Epoch 00123: val_loss did not improve from 0.32502
# Epoch 124/200
# 96/96 [==============================] - 27s 279ms/step - loss: 0.0773 - precision: 0.9772 - recall: 0.9705 - accuracy: 0.9744 - val_loss: 0.3576 - val_precision: 0.9088 - val_recall: 0.8961 - val_accuracy: 0.9029
#
# Epoch 00124: val_loss did not improve from 0.32502
# Epoch 125/200
# 96/96 [==============================] - 26s 273ms/step - loss: 0.0769 - precision: 0.9800 - recall: 0.9728 - accuracy: 0.9760 - val_loss: 0.3355 - val_precision: 0.9137 - val_recall: 0.9015 - val_accuracy: 0.9052
#
# Epoch 00125: val_loss did not improve from 0.32502
# Epoch 126/200
# 96/96 [==============================] - 27s 278ms/step - loss: 0.0745 - precision: 0.9790 - recall: 0.9707 - accuracy: 0.9757 - val_loss: 0.3356 - val_precision: 0.9156 - val_recall: 0.9012 - val_accuracy: 0.9058
#
# Epoch 00126: val_loss did not improve from 0.32502
# Epoch 127/200
# 96/96 [==============================] - 26s 272ms/step - loss: 0.0750 - precision: 0.9780 - recall: 0.9710 - accuracy: 0.9750 - val_loss: 0.3284 - val_precision: 0.9143 - val_recall: 0.9018 - val_accuracy: 0.9058
#
# Epoch 00127: val_loss did not improve from 0.32502
# Epoch 128/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0725 - precision: 0.9812 - recall: 0.9731 - accuracy: 0.9779 - val_loss: 0.3421 - val_precision: 0.9097 - val_recall: 0.8972 - val_accuracy: 0.9021
#
# Epoch 00128: val_loss did not improve from 0.32502
# Epoch 129/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0766 - precision: 0.9765 - recall: 0.9694 - accuracy: 0.9736 - val_loss: 0.3321 - val_precision: 0.9147 - val_recall: 0.8998 - val_accuracy: 0.9063
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 1.6796160707599483e-05.
#
# Epoch 00129: val_loss did not improve from 0.32502
# Epoch 130/200
# 96/96 [==============================] - 26s 267ms/step - loss: 0.0717 - precision: 0.9798 - recall: 0.9731 - accuracy: 0.9760 - val_loss: 0.3578 - val_precision: 0.9105 - val_recall: 0.8975 - val_accuracy: 0.9018
#
# Epoch 00130: val_loss did not improve from 0.32502
# Epoch 131/200
# 96/96 [==============================] - 25s 265ms/step - loss: 0.0736 - precision: 0.9791 - recall: 0.9721 - accuracy: 0.9755 - val_loss: 0.3524 - val_precision: 0.9117 - val_recall: 0.8961 - val_accuracy: 0.9026
#
# Epoch 00131: val_loss did not improve from 0.32502
# Epoch 132/200
# 96/96 [==============================] - 25s 266ms/step - loss: 0.0720 - precision: 0.9803 - recall: 0.9741 - accuracy: 0.9773 - val_loss: 0.3390 - val_precision: 0.9139 - val_recall: 0.9003 - val_accuracy: 0.9063
#
# Epoch 00132: val_loss did not improve from 0.32502
# Epoch 133/200
# 96/96 [==============================] - 26s 266ms/step - loss: 0.0689 - precision: 0.9818 - recall: 0.9747 - accuracy: 0.9781 - val_loss: 0.3381 - val_precision: 0.9136 - val_recall: 0.9003 - val_accuracy: 0.9052
#
# Epoch 00133: val_loss did not improve from 0.32502
# Epoch 134/200
# 96/96 [==============================] - 26s 267ms/step - loss: 0.0705 - precision: 0.9809 - recall: 0.9739 - accuracy: 0.9780 - val_loss: 0.3457 - val_precision: 0.9118 - val_recall: 0.8978 - val_accuracy: 0.9018
#
# Epoch 00134: val_loss did not improve from 0.32502
# Epoch 135/200
# 96/96 [==============================] - 25s 264ms/step - loss: 0.0708 - precision: 0.9806 - recall: 0.9740 - accuracy: 0.9779 - val_loss: 0.3427 - val_precision: 0.9133 - val_recall: 0.8998 - val_accuracy: 0.9041
#
# Epoch 00135: val_loss did not improve from 0.32502
# Epoch 136/200
# 96/96 [==============================] - 26s 268ms/step - loss: 0.0695 - precision: 0.9811 - recall: 0.9741 - accuracy: 0.9774 - val_loss: 0.3465 - val_precision: 0.9142 - val_recall: 0.9003 - val_accuracy: 0.9046
#
# Epoch 00136: val_loss did not improve from 0.32502
# Epoch 137/200
# 96/96 [==============================] - 26s 266ms/step - loss: 0.0673 - precision: 0.9826 - recall: 0.9757 - accuracy: 0.9791 - val_loss: 0.3377 - val_precision: 0.9178 - val_recall: 0.9018 - val_accuracy: 0.9075
#
# Epoch 00137: val_loss did not improve from 0.32502
# Epoch 138/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0677 - precision: 0.9817 - recall: 0.9754 - accuracy: 0.9785 - val_loss: 0.3401 - val_precision: 0.9148 - val_recall: 0.9012 - val_accuracy: 0.9061
#
# Epoch 00138: val_loss did not improve from 0.32502
# Epoch 139/200
# 96/96 [==============================] - 27s 286ms/step - loss: 0.0692 - precision: 0.9801 - recall: 0.9739 - accuracy: 0.9775 - val_loss: 0.3508 - val_precision: 0.9158 - val_recall: 0.9012 - val_accuracy: 0.9069
#
# Epoch 00139: val_loss did not improve from 0.32502
# Epoch 140/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0686 - precision: 0.9805 - recall: 0.9745 - accuracy: 0.9780 - val_loss: 0.3236 - val_precision: 0.9157 - val_recall: 0.9029 - val_accuracy: 0.9089
# Epoch 00140: val_loss improved from 0.32502 to 0.32355, saving model to ./CNN_Models/3_block_cnn\3_blockV2.h5
# Epoch 141/200
# 96/96 [==============================] - 27s 279ms/step - loss: 0.0696 - precision: 0.9795 - recall: 0.9732 - accuracy: 0.9763 - val_loss: 0.3476 - val_precision: 0.9152 - val_recall: 0.9001 - val_accuracy: 0.9058
#
# Epoch 00141: val_loss did not improve from 0.32355
# Epoch 142/200
# 96/96 [==============================] - 27s 282ms/step - loss: 0.0707 - precision: 0.9809 - recall: 0.9734 - accuracy: 0.9774 - val_loss: 0.3550 - val_precision: 0.9138 - val_recall: 0.9018 - val_accuracy: 0.9072
#
# Epoch 00142: val_loss did not improve from 0.32355
# Epoch 143/200
# 96/96 [==============================] - 28s 291ms/step - loss: 0.0677 - precision: 0.9808 - recall: 0.9747 - accuracy: 0.9778 - val_loss: 0.3426 - val_precision: 0.9172 - val_recall: 0.9018 - val_accuracy: 0.9069
#
# Epoch 00143: val_loss did not improve from 0.32355
# Epoch 144/200
# 96/96 [==============================] - 27s 285ms/step - loss: 0.0712 - precision: 0.9804 - recall: 0.9745 - accuracy: 0.9779 - val_loss: 0.3382 - val_precision: 0.9153 - val_recall: 0.9015 - val_accuracy: 0.9055
#
# Epoch 00144: val_loss did not improve from 0.32355
# Epoch 145/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0671 - precision: 0.9801 - recall: 0.9737 - accuracy: 0.9768 - val_loss: 0.3379 - val_precision: 0.9134 - val_recall: 0.9038 - val_accuracy: 0.9083
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 1.007769642455969e-05.
#
# Epoch 00145: val_loss did not improve from 0.32355
# Epoch 146/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0691 - precision: 0.9809 - recall: 0.9740 - accuracy: 0.9773 - val_loss: 0.3435 - val_precision: 0.9139 - val_recall: 0.9032 - val_accuracy: 0.9069
#
# Epoch 00146: val_loss did not improve from 0.32355
# Epoch 147/200
# 96/96 [==============================] - 28s 290ms/step - loss: 0.0698 - precision: 0.9801 - recall: 0.9735 - accuracy: 0.9768 - val_loss: 0.3466 - val_precision: 0.9161 - val_recall: 0.9041 - val_accuracy: 0.9066
#
# Epoch 00147: val_loss did not improve from 0.32355
# Epoch 148/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0662 - precision: 0.9824 - recall: 0.9765 - accuracy: 0.9794 - val_loss: 0.3467 - val_precision: 0.9146 - val_recall: 0.9052 - val_accuracy: 0.9069
#
# Epoch 00148: val_loss did not improve from 0.32355
# Epoch 149/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0680 - precision: 0.9813 - recall: 0.9752 - accuracy: 0.9780 - val_loss: 0.3324 - val_precision: 0.9212 - val_recall: 0.9075 - val_accuracy: 0.9126
#
# Epoch 00149: val_loss did not improve from 0.32355
# Epoch 150/200
# 96/96 [==============================] - 27s 280ms/step - loss: 0.0645 - precision: 0.9814 - recall: 0.9766 - accuracy: 0.9785 - val_loss: 0.3391 - val_precision: 0.9164 - val_recall: 0.9046 - val_accuracy: 0.9086
#
# Epoch 00150: val_loss did not improve from 0.32355
# Epoch 151/200
# 96/96 [==============================] - 27s 279ms/step - loss: 0.0700 - precision: 0.9801 - recall: 0.9736 - accuracy: 0.9764 - val_loss: 0.3414 - val_precision: 0.9179 - val_recall: 0.9041 - val_accuracy: 0.9081
#
# Epoch 00151: val_loss did not improve from 0.32355
# Epoch 152/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0649 - precision: 0.9833 - recall: 0.9768 - accuracy: 0.9802 - val_loss: 0.3438 - val_precision: 0.9160 - val_recall: 0.9032 - val_accuracy: 0.9078
#
# Epoch 00152: val_loss did not improve from 0.32355
# Epoch 153/200
# 96/96 [==============================] - 27s 280ms/step - loss: 0.0678 - precision: 0.9810 - recall: 0.9744 - accuracy: 0.9780 - val_loss: 0.3488 - val_precision: 0.9160 - val_recall: 0.9029 - val_accuracy: 0.9075
#
# Epoch 00153: val_loss did not improve from 0.32355
# Epoch 154/200
# 96/96 [==============================] - 27s 282ms/step - loss: 0.0663 - precision: 0.9818 - recall: 0.9764 - accuracy: 0.9790 - val_loss: 0.3429 - val_precision: 0.9191 - val_recall: 0.9046 - val_accuracy: 0.9089
#
# Epoch 00154: val_loss did not improve from 0.32355
# Epoch 155/200
# 96/96 [==============================] - 28s 289ms/step - loss: 0.0640 - precision: 0.9825 - recall: 0.9777 - accuracy: 0.9803 - val_loss: 0.3317 - val_precision: 0.9193 - val_recall: 0.9043 - val_accuracy: 0.9115
#
# Epoch 00155: val_loss did not improve from 0.32355
# Epoch 156/200
# 96/96 [==============================] - 29s 304ms/step - loss: 0.0638 - precision: 0.9820 - recall: 0.9767 - accuracy: 0.9792 - val_loss: 0.3410 - val_precision: 0.9176 - val_recall: 0.9061 - val_accuracy: 0.9098
#
# Epoch 00156: val_loss did not improve from 0.32355
# Epoch 157/200
# 96/96 [==============================] - 27s 287ms/step - loss: 0.0643 - precision: 0.9819 - recall: 0.9764 - accuracy: 0.9793 - val_loss: 0.3339 - val_precision: 0.9184 - val_recall: 0.9069 - val_accuracy: 0.9103
#
# Epoch 00157: val_loss did not improve from 0.32355
# Epoch 158/200
# 96/96 [==============================] - 27s 284ms/step - loss: 0.0640 - precision: 0.9829 - recall: 0.9776 - accuracy: 0.9803 - val_loss: 0.3416 - val_precision: 0.9163 - val_recall: 0.9038 - val_accuracy: 0.9095
#
# Epoch 00158: val_loss did not improve from 0.32355
# Epoch 159/200
# 96/96 [==============================] - 29s 308ms/step - loss: 0.0653 - precision: 0.9824 - recall: 0.9761 - accuracy: 0.9787 - val_loss: 0.3387 - val_precision: 0.9161 - val_recall: 0.9046 - val_accuracy: 0.9072
#
# Epoch 00159: ReduceLROnPlateau reducing learning rate to 6.046617636457085e-06.
#
# Epoch 00159: val_loss did not improve from 0.32355
# Epoch 160/200
# 96/96 [==============================] - 29s 300ms/step - loss: 0.0614 - precision: 0.9839 - recall: 0.9781 - accuracy: 0.9805 - val_loss: 0.3372 - val_precision: 0.9157 - val_recall: 0.9058 - val_accuracy: 0.9086
#
# Epoch 00160: val_loss did not improve from 0.32355
# Epoch 161/200
# 96/96 [==============================] - 28s 296ms/step - loss: 0.0626 - precision: 0.9832 - recall: 0.9761 - accuracy: 0.9794 - val_loss: 0.3491 - val_precision: 0.9150 - val_recall: 0.9012 - val_accuracy: 0.9061
#
# Epoch 00161: val_loss did not improve from 0.32355
# Epoch 162/200
# 96/96 [==============================] - 29s 303ms/step - loss: 0.0645 - precision: 0.9821 - recall: 0.9755 - accuracy: 0.9787 - val_loss: 0.3458 - val_precision: 0.9162 - val_recall: 0.9023 - val_accuracy: 0.9075
#
# Epoch 00162: val_loss did not improve from 0.32355
# Epoch 163/200
# 96/96 [==============================] - 29s 306ms/step - loss: 0.0659 - precision: 0.9827 - recall: 0.9765 - accuracy: 0.9798 - val_loss: 0.3395 - val_precision: 0.9171 - val_recall: 0.9038 - val_accuracy: 0.9083
#
# Epoch 00163: val_loss did not improve from 0.32355
# Epoch 164/200
# 96/96 [==============================] - 27s 283ms/step - loss: 0.0639 - precision: 0.9811 - recall: 0.9758 - accuracy: 0.9788 - val_loss: 0.3393 - val_precision: 0.9167 - val_recall: 0.9046 - val_accuracy: 0.9075
#
# Epoch 00164: val_loss did not improve from 0.32355
# Epoch 165/200
# 96/96 [==============================] - 27s 282ms/step - loss: 0.0653 - precision: 0.9814 - recall: 0.9756 - accuracy: 0.9781 - val_loss: 0.3478 - val_precision: 0.9171 - val_recall: 0.9032 - val_accuracy: 0.9072
#
# Epoch 00165: val_loss did not improve from 0.32355
# Epoch 166/200
# 96/96 [==============================] - 27s 282ms/step - loss: 0.0630 - precision: 0.9833 - recall: 0.9773 - accuracy: 0.9802 - val_loss: 0.3408 - val_precision: 0.9186 - val_recall: 0.9055 - val_accuracy: 0.9106
#
# Epoch 00166: val_loss did not improve from 0.32355
# Epoch 167/200
# 96/96 [==============================] - 27s 281ms/step - loss: 0.0598 - precision: 0.9851 - recall: 0.9792 - accuracy: 0.9822 - val_loss: 0.3352 - val_precision: 0.9196 - val_recall: 0.9049 - val_accuracy: 0.9106
#
# Epoch 00167: val_loss did not improve from 0.32355
# Epoch 168/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0636 - precision: 0.9828 - recall: 0.9774 - accuracy: 0.9802 - val_loss: 0.3453 - val_precision: 0.9174 - val_recall: 0.9035 - val_accuracy: 0.9078
#
# Epoch 00168: val_loss did not improve from 0.32355
# Epoch 169/200
# 96/96 [==============================] - 27s 282ms/step - loss: 0.0607 - precision: 0.9838 - recall: 0.9781 - accuracy: 0.9810 - val_loss: 0.3489 - val_precision: 0.9155 - val_recall: 0.9035 - val_accuracy: 0.9066
#
# Epoch 00169: val_loss did not improve from 0.32355
# Epoch 170/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.0613 - precision: 0.9831 - recall: 0.9779 - accuracy: 0.9806 - val_loss: 0.3343 - val_precision: 0.9194 - val_recall: 0.9049 - val_accuracy: 0.9103
#
# Epoch 00170: val_loss did not improve from 0.32355
# Epoch 171/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.0643 - precision: 0.9828 - recall: 0.9767 - accuracy: 0.9798 - val_loss: 0.3434 - val_precision: 0.9152 - val_recall: 0.9032 - val_accuracy: 0.9078
#
# Epoch 00171: val_loss did not improve from 0.32355
# Epoch 172/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0638 - precision: 0.9826 - recall: 0.9766 - accuracy: 0.9794 - val_loss: 0.3383 - val_precision: 0.9181 - val_recall: 0.9032 - val_accuracy: 0.9086
#
# Epoch 00172: val_loss did not improve from 0.32355
# Epoch 173/200
# 96/96 [==============================] - 26s 275ms/step - loss: 0.0623 - precision: 0.9837 - recall: 0.9769 - accuracy: 0.9807 - val_loss: 0.3345 - val_precision: 0.9176 - val_recall: 0.9063 - val_accuracy: 0.9101
#
# Epoch 00173: ReduceLROnPlateau reducing learning rate to 3.6279706364439334e-06.
#
# Epoch 00173: val_loss did not improve from 0.32355
# Epoch 174/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.0620 - precision: 0.9832 - recall: 0.9781 - accuracy: 0.9809 - val_loss: 0.3413 - val_precision: 0.9196 - val_recall: 0.9046 - val_accuracy: 0.9101
#
# Epoch 00174: val_loss did not improve from 0.32355
# Epoch 175/200
# 96/96 [==============================] - 26s 274ms/step - loss: 0.0630 - precision: 0.9827 - recall: 0.9765 - accuracy: 0.9798 - val_loss: 0.3479 - val_precision: 0.9160 - val_recall: 0.9035 - val_accuracy: 0.9069
#
# Epoch 00175: val_loss did not improve from 0.32355
# Epoch 176/200
# 96/96 [==============================] - 27s 279ms/step - loss: 0.0596 - precision: 0.9829 - recall: 0.9777 - accuracy: 0.9803 - val_loss: 0.3431 - val_precision: 0.9193 - val_recall: 0.9043 - val_accuracy: 0.9086
#
# Epoch 00176: val_loss did not improve from 0.32355
# Epoch 177/200
# 96/96 [==============================] - 26s 271ms/step - loss: 0.0649 - precision: 0.9824 - recall: 0.9769 - accuracy: 0.9801 - val_loss: 0.3404 - val_precision: 0.9185 - val_recall: 0.9046 - val_accuracy: 0.9095
#
# Epoch 00177: val_loss did not improve from 0.32355
# Epoch 178/200
# 96/96 [==============================] - 27s 281ms/step - loss: 0.0615 - precision: 0.9845 - recall: 0.9782 - accuracy: 0.9818 - val_loss: 0.3391 - val_precision: 0.9174 - val_recall: 0.9041 - val_accuracy: 0.9092
#
# Epoch 00178: val_loss did not improve from 0.32355
# Epoch 179/200
# 96/96 [==============================] - 27s 277ms/step - loss: 0.0627 - precision: 0.9828 - recall: 0.9768 - accuracy: 0.9800 - val_loss: 0.3414 - val_precision: 0.9178 - val_recall: 0.9049 - val_accuracy: 0.9081
#
# Epoch 00179: val_loss did not improve from 0.32355
# Epoch 180/200
# 96/96 [==============================] - 26s 276ms/step - loss: 0.0619 - precision: 0.9839 - recall: 0.9773 - accuracy: 0.9807 - val_loss: 0.3381 - val_precision: 0.9191 - val_recall: 0.9049 - val_accuracy: 0.9092
# Restoring model weights from the end of the best epoch.
#
# Epoch 00180: val_loss did not improve from 0.32355
# Epoch 00180: early stopping

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
loss = hist.history['loss']
val_loss = hist.history['val_loss']
precision = hist.history['precision']
val_precision = hist.history['val_precision']
recall = hist.history['recall']
val_recall = hist.history['val_recall']

# Plot the graph manually
epochs = range(len(loss))

plt.figure(figsize=(25, 25))
plt.subplot(4, 1, 1)
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.subplot(4, 1, 2)
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(epochs, precision, 'r', label='Training Precision')
plt.plot(epochs, val_precision, 'b', label='Validation Precision')
plt.title('Training and validation Precision')
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(epochs, recall, 'r', label = "Training Recall")
plt.plot(epochs, val_recall, 'b', label='Validation Recall')
plt.title('Training and validation Recall')
plt.legend()

plt.show()

# %%
model.evaluate(validation_ds)
# Out:
# 28/28 [==============================] - 2s 68ms/step - loss: 0.3236 - precision: 0.9157 - recall: 0.9029 - accuracy: 0.9089
# [0.3235528767108917,
#  0.9157254695892334,
#  0.9029126167297363,
#  0.9089092016220093]

# %%
model.save('./CNN_Models/3_block_cnn/3_blockV2.h5')

# %%
model = models.load_model('CNN_Models/3_block_cnn/3_blockV2.h5')

# %%
model.summary()
# Out:
# Model: "2_block_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Original_Image (InputLayer)  [(None, 256, 256, 5)]     0
# _________________________________________________________________
# random_flip_29 (RandomFlip)  (None, 256, 256, 5)       0
# _________________________________________________________________
# random_rotation_29 (RandomRo (None, 256, 256, 5)       0
# _________________________________________________________________
# rescaling_29 (Rescaling)     (None, 256, 256, 5)       0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 128, 128, 64)      2944
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# re_lu_56 (ReLU)              (None, 64, 64, 64)        0
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_57 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# re_lu_57 (ReLU)              (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_118 (Conv2D)          (None, 8, 8, 128)         147584
# _________________________________________________________________
# conv2d_119 (Conv2D)          (None, 4, 4, 128)         147584
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# re_lu_58 (ReLU)              (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 821,193
# Trainable params: 820,553
# Non-trainable params: 640
# _________________________________________________________________

# %%
model.compile()

# %%
test = tfds.as_numpy(test_ds)
y_pred = []
y_label = []

for i in test:
  flat_img = i[0]
  flat_label = i[1]
  pred = model.predict(flat_img)
  pred = np.argmax(pred, axis=1)
  y_pred.extend(pred)
  y_label.extend(np.argmax(flat_label, axis = 1))

y_pred = np.array(y_pred)
y_label = np.array(y_label)

# %%
len(y_pred)
# Out:
# 1751

# %%
from sklearn.metrics import classification_report

print(y_pred)
print(classification_report(y_label, y_pred))
# Out:
# [8 8 8 ... 8 2 8]
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73       103
#            1       0.91      0.81      0.86        90
#            2       0.94      0.85      0.90       116
#            3       0.81      0.91      0.86       105
#            4       0.80      0.83      0.82       108
#            5       0.93      0.85      0.89        98
#            6       0.92      0.86      0.89       114
#            7       0.85      0.88      0.87       129
#            8       0.92      0.95      0.93       888
#
#     accuracy                           0.89      1751
#    macro avg       0.88      0.85      0.86      1751
# weighted avg       0.89      0.89      0.89      1751
